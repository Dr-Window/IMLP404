# %%
#導入需要的依賴包
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
x = np.arange(1,5)
y = [9,9,6,8]
plt.title("Try Seaborn")
plt.xlabel("X axis")
plt.ylabel("Y axis")
sns.set(style='whitegrid')
sns.set_context('paper')
plt.bar(x,y)
plt.show()

# %%
x = np.linspace(-2*np.pi, 2*np.pi, 100)
plt.xlim(-6,6)
plt.ylim(-1.2,1.2)

plt.tight_layout()
sns.set(style='darkgrid')
plt.subplot(4,1,1)
plt.plot(x, np.sin(x), lw = 3, label='$\sin$')
plt.plot(x, np.cos(x), lw = 3, label='$\cos$')
plt.legend(loc=3)
sns.despine()

plt.subplot(4,1,2) 
sns.set(style='ticks')
plt.plot(x, np.sin(x), lw = 3, label='$\sin$')
plt.plot(x, np.cos(x), lw = 3, label='$\cos$')
plt.legend(loc=3)
sns.despine()

plt.subplot(4,1,3) 
sns.set(style='whitegrid')
plt.plot(x, np.sin(x), lw = 3, label='$\sin$')
plt.plot(x, np.cos(x), lw = 3, label='$\cos$')
plt.legend(loc=3)
sns.despine()

plt.subplot(4,1,4) 
sns.set(style='dark')
plt.plot(x, np.sin(x), lw = 3, label='$\sin$')
plt.plot(x, np.cos(x), lw = 3, label='$\cos$')
plt.legend(loc=3)
sns.despine()

# %%
x = np.arange(1,6)
y = [5,4,8,7,3]
plt.title("Test Bar")
plt.xlabel('X axis')
plt.ylabel('Y axis')
sns.set(context = 'notebook',style="darkgrid", font = 'sans-srif')
plt.bar(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x = np.linspace(-2*np.pi, 2*np.pi, 100)
plt.xlim(-6,6)
plt.ylim(-1.2,1.2)
plt.plot(x, np.sin(x), lw = 3, label='$\sin$')
plt.plot(x, np.cos(x), lw = 3, label='$\cos$')

plt.legend(loc=3)
# Out:
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family ['sans-srif'] not found. Falling back to DejaVu Sans.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.
# findfont: Font family 'sans-srif' not found.

# %% [markdown]
# # #統計預測圖
# seaborn.relplot() 是一個非常好用的繪圖指令, 可以一次把數個變數的關係呈現在一張圖表上.
#
# `load_dataset` looks for online csv files on https://github.com/mwaskom/seaborn-data. Here's the docstring:<br>
#
# Load a dataset from the online repository (requires internet).<br>
#
# >Parameters
#
# >name : str Name of the dataset (name.csv on https://github.com/mwaskom/seaborn-data). You can obtain list of available datasets using func:get_dataset_names<br>
# kws : dict, optional Passed to pandas.read_csv

# %%
#Seaborn統計預測圖
#加載sns內置數據集 
tips = sns.load_dataset("tips")
sns.set(color_codes = True)
tips.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# 內建數據集-tips數據集
# > 關於數據集，total_bill是消費總金額，tip是小費，size指用餐人數。

# %%
NBA = sns.load_dataset('data/NBA_season1718_salary.csv')
#sns.load_dataset只能針對內建數據集
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 NBA = sns.load_dataset('data/NBA_season1718_salary.csv')
#
# File ~\anaconda3\Lib\site-packages\seaborn\utils.py:587, in load_dataset(name, cache, data_home, **kws)
#     585 if not os.path.exists(cache_path):
#     586     if name not in get_dataset_names():
# --> 587         raise ValueError(f"'{name}' is not one of the example datasets.")
#     588     urlretrieve(url, cache_path)
#     589 full_path = cache_path
#
# ValueError: 'data/NBA_season1718_salary.csv' is not one of the example datasets.

# %%
#匯入自己的數據
data = pd.read_csv('data/NBA_season1718_salary.csv')
data
# Out:
#      Unnamed: 0          Player   Tm  season17_18
# 0             1   Stephen Curry  GSW   34682550.0
# 1             2    LeBron James  CLE   33285709.0
# 2             3    Paul Millsap  DEN   31269231.0
# 3             4  Gordon Hayward  BOS   29727900.0
# 4             5   Blake Griffin  DET   29512900.0
# ..          ...             ...  ...          ...
# 568         569      Quinn Cook  NOP      25000.0
# 569         570   Chris Johnson  HOU      25000.0
# 570         571      Beno Udrih  DET      25000.0
# 571         572   Joel Bolomboy  MIL      22248.0
# 572         573    Jarell Eddie  CHI      17224.0
#
# [573 rows x 4 columns]

# %% [markdown]
# # #單變量分析繪圖（直方圖、條形圖）
# > Dataset: NBA_season1718_salary.csv<br>
# ref:https://www.kaggle.com/koki25ando/salary

# %%
#對讀進來的數據按薪資降序排序並取前10條數據
salary_top10 = (data.sort_values('season17_18', ascending = False)).head(10)
salary_top10
# Out:
#    Unnamed: 0             Player   Tm  season17_18
# 0           1      Stephen Curry  GSW   34682550.0
# 1           2       LeBron James  CLE   33285709.0
# 2           3       Paul Millsap  DEN   31269231.0
# 3           4     Gordon Hayward  BOS   29727900.0
# 4           5      Blake Griffin  DET   29512900.0
# 5           6         Kyle Lowry  TOR   28703704.0
# 6           7  Russell Westbrook  OKC   28530608.0
# 7           8        Mike Conley  MEM   28530608.0
# 8           9       James Harden  HOU   28299399.0
# 9          10      DeMar DeRozan  TOR   27739975.0

# %%
#取出球員列數據，作為條形圖橫坐標

player = salary_top10['Player']

#取出球員薪資列，作為條形圖縱坐標

season_salary = salary_top10['season17_18']

# %%
plt.figure(figsize = (10,6))
plt.xticks(rotation = 45)
plt.ylim(season_salary.min() *0.5, season_salary.max() * 1.01)
#ci參數表示允許的誤差範圍（控制誤差棒的百分比，在0-100之間）
sns.barplot(x  = player, y = season_salary, data = salary_top10, ci=68)
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Result
#
# 從條形圖中不難看出，勇士隊的當家球星curry資最高，將近達到3500萬美元，位居第二的是勒布朗詹姆斯，也是在3300萬美元以上。上面的條形圖是按球員作為橫坐標，下面我們按球隊匯總，看看哪個球隊的薪資總額最高。

# %% [markdown]
# # 練習 - 彙總球隊薪資繪製成直方圖
# 按球隊匯總，看看哪個球隊的薪資總額最高。

# %%
salary_by_team = data.groupby(by='Tm').sum()
salary_by_team
# Out:
#      Unnamed: 0                                             Player  \
# Tm
# ATL        9324  Kent BazemoreDennis SchroderMiles PlumleeJamal...
# BOS        4712  Gordon HaywardAl HorfordKyrie IrvingJayson Tat...
# BRK        4953  Allen CrabbeTimofey MozgovDeMarre CarrollJerem...
# CHI        7551  Dwyane WadeRobin LopezOmer AsikCristiano Felic...
# CHO        3061  Dwight HowardNicolas BatumMarvin WilliamsMicha...
# CLE        2979  LeBron JamesKevin LoveGeorge HillTristan Thomp...
# DAL        7636  Harrison BarnesWesley MatthewsDwight PowellJos...
# DEN        3624  Paul MillsapMason PlumleeKenneth FariedWilson ...
# DET        5639  Blake GriffinAndre DrummondReggie JacksonJon L...
# GSW        3892  Stephen CurryKevin DurantKlay ThompsonDraymond...
# HOU        7363  James HardenChris PaulRyan AndersonEric Gordon...
# IND        5653  Victor OladipoThaddeus YoungBojan BogdanovicDa...
# LAC        5891  DeAndre JordanDanilo GallinariTobias HarrisAus...
# LAL        7241  Brook LopezKentavious Caldwell-PopeLuol DengCo...
# MEM        6557  Mike ConleyChandler ParsonsMarc GasolJaMychal ...
# MIA        4392  Chris BoshHassan WhitesideGoran DragicJames Jo...
# MIL        6485  Giannis AntetokounmpoEric BledsoeKhris Middlet...
# MIN        3482  Jimmy ButlerJeff TeagueGorgui DiengTaj GibsonN...
# NOP        6775  Jrue HolidayAnthony DavisDeMarcus CousinsNikol...
# NYK        6024  Enes KanterJoakim NoahTim HardawayCourtney Lee...
# OKC        3246  Russell WestbrookCarmelo AnthonySteven AdamsPa...
# ORL        4567  Evan FournierBismack BiyomboNikola VucevicTerr...
# PHI        6194  J.J. RedickRobert CovingtonAmir JohnsonTrevor ...
# PHO        6290  Greg MonroeBrandon KnightTyson ChandlerJared D...
# POR        5307  Damian LillardC.J. McCollumEvan TurnerMaurice ...
# SAC        5164  Zach RandolphIman ShumpertJoe JohnsonBogdan Bo...
# SAS        4467  LaMarcus AldridgeKawhi LeonardPau GasolTony Pa...
# TOR        5109  Kyle LowryDeMar DeRozanSerge IbakaJonas Valanc...
# UTA        5855  Rudy GobertRicky RubioJoe InglesDerrick Favors...
# WAS        5018  Otto PorterBradley BealJohn WallIan MahinmiMar...
#
#      season17_18
# Tm
# ATL  100217797.0
# BOS  115009962.0
# BRK   96039772.0
# CHI   89425042.0
# CHO  117228164.0
# CLE  137288549.0
# DAL   85821361.0
# DEN  107889099.0
# DET  120086105.0
# GSW  137494845.0
# HOU  119024081.0
# IND   94429791.0
# LAC  118907163.0
# LAL  105355450.0
# MEM  110104061.0
# MIA  131222624.0
# MIL  120686318.0
# MIN  117468554.0
# NOP  119725571.0
# NYK  107855405.0
# OKC  134294056.0
# ORL   96925954.0
# PHI  100794278.0
# PHO   94818333.0
# POR  119108924.0
# SAC   95627528.0
# SAS  116153554.0
# TOR  116528796.0
# UTA  107465014.0
# WAS  124179842.0

# %%
#先將資料集用groupby根據球隊分別匯總
salary_by_team = data.groupby(by='Tm').sum().reset_index()

salary_by_team = salary_by_team.sort_values(by = "season17_18", ascending = False)

tm_top10 = salary_by_team[1:10]

tm = tm_top10['Tm']

salary_sum = tm_top10["season17_18"]

sns.barplot(x=tm, y=salary_sum , data = tm_top10)

sns.color_palette('hls',10)

sns.set(style='whitegrid')

# %%
from scipy import stats

# %%
#生成參數
x = np.random.gamma(6, size = 200)
sns.distplot(x, kde = False, fit = stats.gamma)
mean, cov = [0,0], [(1, .5), (.5, 1)]
data = np.random.multivariate_normal(mean, cov, 200)
#製圖
df = pd.DataFrame(data, columns = ['x','y'])
sns.jointplot(x = 'x', y = 'y', data = df)

# %% [markdown]
# # #seaborn回歸分析繪圖（regplot）

# %%
#導入依賴包 
# %matplotlib inline 
import numpy as np 
import pandas as pd 
import matplotlib as mpl 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
#加載sns內置數據集 
tips = sns.load_dataset("tips")
sns.set(color_codes = True)
tips.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
# hue= : 可以依照選擇 item 以顏色區分
sns.relplot(x='total_bill', y='tip', data=tips, hue='smoker')

# %%
sns.relplot(x='total_bill', y= 'tip', col = 'time', hue = 'smoker', style = 'smoker', size = 'size', data = tips)

# %% [markdown]
# 內建數據集-tips數據集
# > 關於數據集，total_bill是消費總金額，tip是小費，size指用餐人數。

# %%
#繪製線性回歸模型圖
sns.regplot(x='total_bill', y='tip', data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# # [練習]看看其他變量和小費之間的關係。

# %%
sns.regplot(x='size', y='tip', data=tips)
# Out:
# <Axes: xlabel='size', ylabel='tip'>

# %%
sns.regplot(x='size', y='tip', data=tips, x_jitter = 0.3)

'''
{x,y}_jitterfloats, optional
Add uniform random noise of this size to either the x or y variables. 
The noise is added to a copy of the data after fitting the regression, and only influences the look of the scatterplot. 
This can be helpful when plotting variables that take discrete values.
'''
# Out:
# <Axes: xlabel='size', ylabel='tip'>

# %%
#導入依賴包 %matplotlib inline 
import matplotlib.pyplot as plt 
import seaborn as sns 
sns.set(style="whitegrid", color_codes=True) 
tips = sns.load_dataset("tips")

# %%
sns.distplot(tips['total_bill'])
sns.distplot(tips['tip'])
# Out:
# <Axes: xlabel='tip', ylabel='Density'>

# %% [markdown]
# # #散點圖（分布散點、分簇散點圖）

# %%
sns.scatterplot(x='total_bill', y='tip', data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.set(style="darkgrid", color_codes=True) 
sns.stripplot(x='total_bill', y='tip', data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# 從上面的圖中可以看到，stripplot參數中的x是橫軸數據（分類數據），y是縱軸數據（類型對應數據），由於我們將總金額作為分類，導致分類太多，橫軸數據根本看不清，所以我們重新傳參，分別看下性別和小費、時間和小費，用餐日期跟小費之間的數據分布。

# %%
sns.stripplot(x='sex', y='tip', data=tips, palette =['b', 'orange'])
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.stripplot(x='day', y='tip', data=tips, palette = "Set1")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.stripplot(x='time', y='tip', data=tips, palette = "Set1")
# Out:
# <Axes: xlabel='time', ylabel='tip'>

# %%
sns.stripplot(x='smoker', y='tip', data=tips, palette = "Set1")
# Out:
# <Axes: xlabel='smoker', ylabel='tip'>

# %% [markdown]
# 因為jitter（數據抖動）這個參數的默認值是True,如果我們將其設置為False，效果如圖：

# %%
sns.stripplot(x='smoker', y='tip', data=tips, jitter = False, palette = "Set1")
# Out:
# <Axes: xlabel='smoker', ylabel='tip'>

# %%
sns.swarmplot(x='day',y='tip',data=tips, palette = "Set2")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %% [markdown]
# 在stripplot函數中，我們只看了某一類別對應的數據，而沒有看類中對應其他類的數據分布，舉個例子，比如我們用stripplot看到男性和女性對應的小費數據，但是不知道男性和女性對應的數據中哪些是吸菸的，哪些是不吸菸的，對於這個問題這兩個函數都有一個hue參數，這裡我們就以分簇散點圖函數為例，演示下這個參數的效果，如圖：

# %%
sns.swarmplot(x='day',y='tip',data=tips, hue = 'sex')
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %% [markdown]
# 上面這個圖就很好的展示了不同性別在不同的星期中付小費數據的分布。

# %% [markdown]
# # #繪製盒圖、小提琴圖
# seaborn.boxplot()
# 這個函數主要是繪製出一個箱型圖來反映離群點數據。

# %%
sns.boxplot(x='tip', data = tips)
# Out:
# <Axes: xlabel='tip'>

# %%
sns.boxplot(y='tip', data = tips)
# Out:
# <Axes: ylabel='tip'>

# %%
sns.boxplot(y='tip', x = 'day', data = tips)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %% [markdown]
# seaborn庫中的很多繪圖方法就是提前給你畫好模板，我們只需要把數據傳進去就得到相應的圖形，
# 基於此，我門是不是可以在同一個模板上同時繪製分簇圖和箱型圖呢？

# %%
sns.boxplot(y='total_bill', x = 'day', data = tips)
sns.swarmplot(y='total_bill', x='day',data=tips, color='.25')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(y='tip', x = 'day', data = tips)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %% [markdown]
# 小提琴圖即反映了數據的離群情況，同時也反映了數據的分布密度。<br>
# 此函數跟箱型圖一樣，也有hue參數，可以查看第二個分類屬性下的數據分布，如下：

# %%
sns.violinplot(y='tip', x = 'day', hue= 'sex',data = tips)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %% [markdown]
# 可以看到，上面的小提琴圖是4對8個，即當設置hue參數為sex時，每個小提琴的數據集是一類數據，那有沒有辦法讓男性對應數據和女性對應數據都作為一個數據集繪製出一個小提琴圖，只是在一個圖中區分男性數據和女性數據呢？答案是肯定的，violinplot()函數提供了一個split參數，可以做到以上需求，如下：

# %%
sns.violinplot(y='tip', x = 'day', hue= 'sex',data = tips, split = True)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %% [markdown]
# 除此以外，我們再來看一下inner參數，上面的小提琴圖中內部都是箱型圖，通過inner參數，我們可以設置其他類型，inner可選參數有：box、quartile(四分位)、point、stick。我們依次看下：

# %%
sns.violinplot(y='tip', x = 'day', hue= 'sex',data = tips, split = True, inner='box')
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.violinplot(y='tip', x = 'day', hue= 'sex',data = tips, split = True, inner='quartile')
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.violinplot(y='tip', x = 'day', hue= 'sex',data = tips, split = True, inner='point')
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.violinplot(y='tip', x = 'day', hue= 'sex',data = tips, split = True, inner='stick')
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %% [markdown]
# # #結構化展示多維數據
# ***Visualizing the multidimensional relationships among the samples is as easy as calling sns.pairplot:***

# %%
sns.pairplot(tips, hue = 'sex', height = 2.5)

# %% [markdown]
# 使用FacetGrid時，我們會通過一個pandas DataFrame以及控制圖形網格的行、列和顏色的變量名稱來初始化一個對象。這些維度變量（控制行、列和顏色的變量）應該是分類變量或者離散變量，然後這些變量的不同水平組合起來就構成了整個圖形的每一個子圖（facet，在這裡可以理解為我們維度拆解的最小粒度）
#
#
# 這一函數的目標是一步到位地提供一幅完整的成品圖，它在完成繪圖後還會對每個坐標軸添加注釋。

# %%
g = sns.FacetGrid(tips, col='time')

# %%
g = sns.FacetGrid(tips, col='time') 
g.map(plt.hist, 'tip')

# %%
g = sns.FacetGrid(tips, col='sex', hue = 'smoker') 
g.map(plt.scatter, 'total_bill', 'tip', alpha=.7)
g.add_legend()

# %% [markdown]
# 我們可以指定某個seaborn調色板，也可以通過字典將hue變量中的每個分類與其對應的matplotlib顏色傳遞給函數<br>
# （這樣就可以隨心所以使用大量的matplotlib支持的色彩）

# %%
pal = dict(Lunch = 'seagreen', Dinner = 'gray')
g = sns.FacetGrid(tips, hue = 'time', palette = pal, height = 5)
g.map(plt.scatter, "total_bill", 'tip', s = 50, alpha = .7, linewidth = .5, edgecolor = 'white')
g.add_legend()

# %%
tips = sns.load_dataset('iris')
g = sns.PairGrid(tips)
g.map(plt.scatter);

# %% [markdown]
# map_diag()函數是繪製對角線上的單變量子圖，mag_offdiag是繪製對角線以外的兩個變量間的子圖。

# %%
g = sns.PairGrid(tips)
g = g.map_diag(plt.hist, edgecolor = "w")
g = g.map_offdiag(plt.scatter, edgecolor = "w", s = 40)

# %% [markdown]
# # [練習]試著讀取自己的資料，繪製出多維數據圖表

# %%
#導入需要的依賴包
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
REH = pd.read_csv('D:/ML/IMLP404/Unit02/data/Reh_VT.csv')

# %%
sns.set(context = 'notebook',style="darkgrid")
plt.xticks(np.arange(0,43,3.5))
sns.histplot(REH, x="Accumulated Time", binwidth = 3.5, binrange = (0,42), hue = "Type of Exercise")
plt.xlabel('Accumulated time for exercise (in hours)')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
plt.xticks(np.arange(0,43,3.5))
sns.histplot(REH, x="Accumulated Time", binwidth = 3.5, binrange = (0,42), hue = "Type of Exercise",multiple='stack')
plt.xlabel('Accumulated time for exercise (in hours)')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
g = sns.PairGrid(REH)
g = g.map_diag(plt.hist, edgecolor = "w")
g = g.map_offdiag(plt.scatter, edgecolor = "w", s = 40)
