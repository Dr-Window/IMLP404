# %%
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

labels = ["Python","C++","Java","JS","C","C#"]
index = np.arange(len(labels))
ratings = [5.16,5.73,14.99,3.17,11.86,4.45]
change = [1.12,0.3,-1.69,0.29,3.41,-0.45]
plt.bar(index, ratings)
plt.xticks(index,labels)
plt.xlabel('Coding type')
plt.ylabel('Use rate')
plt.title("Era for Coding")
# Out:
# Text(0.5, 1.0, 'Era for Coding')

# %%
plt.barh(index,change)
plt.xticks(index,labels)
plt.ylabel("Change")
plt.title("Programming rating")
plt.show()

# %%
x = [21,42,23,4,5,26,77,88,9,10,31,32,33,34,35,36,37,18,49,50,100]
num_bins = 5
n, bins, patches = plt.hist(x,num_bins)
print(n)
print(bins)
print(patches)
plt.show()
# Out:
# [7. 9. 2. 1. 2.]
# [  4.   23.2  42.4  61.6  80.8 100. ]
# <BarContainer object of 5 artists>

# %%
labels = ["Python","C++","Java","JS","C","C#"]
ratings = [5,6,15,3,12,4]
plt.pie(ratings, labels = labels)
plt.title("Rate of use")
plt.axis('equal')
plt.show()

# %%
plt.bar(index,ratings)
plt.xticks(index,labels)
plt.ylabel("Change")
plt.title("Programming rating")
plt.show()

# %%
x = np.linspace(0,10,50)
sinus = np.sin(x)
sinhs = np.sinh(x)
plt.plot(x, sinus, "r--o")
plt.plot(x, sinhs, 'g--')
plt.show()

# %%
x = np.linspace(0,10,50)
sinus = np.sin(x)
sinhs = np.sinh(x)
plt.subplot(2,1,1)
plt.plot(x, sinus, "r--o")
plt.subplot(2,1,2)
plt.plot(x, sinhs, 'g--')
plt.show()

# %%
x = np.linspace(0,10,50)
sinus = np.sin(x)
sinhs = np.sinh(x)

# %%
#多軸圖表：共用X.Y軸
fig, ax = plt.subplots()
ax.plot(x,sinus,'r-o')
ax2 = ax.twinx() #ax與ax2共用
ax2.plot(x,sinhs,'g--')
plt.show()
